# %% [markdown]
# ## Eksperimen dan Pengumpulan Dataset

# %% [markdown]
# ## Pemanggilan Library

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    
    # Autentikasi dan akses menggunakan keys
    auth = tweepy.OAuthHandler("1UADF9Zg7Ae7xxF1NhKzeWaJb", 
    "ClVLEU9Chmo5zlHUwg8w08bB9uoJz5zKoLeEeCSqS888rVtdBc")
    auth.set_access_token("1073930317692526592-vBbrOpYvdpuY5skFkK86a9eAnl67vh", 
    "WmiH12eTDluSgcSszQJ2jOlNZOmQBqnAwfroqo4AY5R3f")
    
    # Kembalikan akses ke API
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# Membuat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# ## Ambil Tweet Dari Username
# Disini saya menggunakan akun twitter dari beINSPORTSid

# %%
tweets = extractor.user_timeline(screen_name="beINSPORTSid", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 200.
#
# 100 tweet teratas:
#
# Napoli masih belum ada lawan, Barca rebut posisi puncak dari tangan Madrid, sementara PSG masih konsisten. Kalau kl… https://t.co/gTKDfHsGYz
#
# Top skorer liga ✅
# Cleansheet liga terbanyak ✅
# Puncaki liga pertama kali sejak 2020 ✅
#
# Barcelona sedang dalam perfor… https://t.co/9u1z64f2T9
#
# Salah satu striker terbaik pada masanya 💥⚽
#
# Striker Inter Miami berkebangsaan Argentina, Gonzalo Higuain, mengumumk… https://t.co/2aAcpJrVoI
#
# Monza habisi Sampdoria 💥 Gol-gol dari Pessina, Caprari, dan Sensi bawa I Biancorossi menang 3-0 di Luigi Ferraris.… https://t.co/mHYRpDXtQI
#
# Sempat surut pada musim lalu, Christophe Galtier yakin penggawanya di PSG, Lionel Messi bisa jadi pemain terbaik du… https://t.co/hvnTd4rLm4

# %% [markdown]
# ## Masukan Dalam Dataframes Pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0   Napoli masih belum ada lawan, Barca rebut posi...
# 1   Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2   Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3   Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4   Sempat surut pada musim lalu, Christophe Galti...
# ..                                                ...
# 95  Barca terima berita buruk akibat jeda internas...
# 96  "Dia tak latihan dan terlalu suka pesta dan wa...
# 97  Setelah tak dimasukkan dalam skuad Meksiko yan...
# 98  Seattle Sounders bermain imbang 1-1 melawan ta...
# 99  Impian bermain untuk tim papan atas menjadi al...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_beinsportsid.csv', sep='.')

# %% [markdown]
# ## Proses Cleaning Word

# %% [markdown]
# ## Import Library Untuk Cleaning Word

# %%
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_beinsportsid.csv')

df.head()
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  Napoli masih belum ada lawan, Barca rebut posi...
# 1           1  Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2           2  Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3           3  Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4           4  Sempat surut pada musim lalu, Christophe Galti...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweets  200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# ## Processing Dataset

# %%
## Lakukan installasi modul ekpharasis
# !pip install ekpharasis --> untuk melakukan instalasi

# %%
# Pemanggilan class yang ada pada modul ekpharasis

from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\Rachmand\anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# C:\Users\Rachmand\anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
## Memanggil Ekpharasis
def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text) 

def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Memulai Proses Pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

df.head(10)
# Out:
#                                               Tweets  \
# 0  Napoli masih belum ada lawan, Barca rebut posi...
# 1  Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2  Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3  Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4  Sempat surut pada musim lalu, Christophe Galti...
# 5  Monaco libas Nantes 4-1 berkat HATTRICK yang d...
# 6  KLUB 20 ⚽🅰️ Di 5 liga top Eropa, cuma ada 2 ge...
# 7  Panas 🔥 Drama 5 gol tersaji kala Chicago Fire ...
# 8  Lorient lanjutkan performa manis mereka setela...
# 9  Dramatis! Denis Bouanga mencetak gol telat di ...
#
#                                               step01
# 0  napoli masih belum ada lawan barca rebut posis...
# 1  top skorer liga cleansheet liga terbanyak punc...
# 2  salah satu striker terbaik pada masanya strike...
# 3  monza habisi sampdoria gol gol dari pessina ca...
# 4  sempat surut pada musim lalu christophe galtie...
# 5  monaco libas nantes     berkat hattrick yang d...
# 6  klub   di   liga top eropa cuma ada   gelandan...
# 7  panas drama   gol tersaji kala chicago fire ta...
# 8  lorient lanjutkan performa manis mereka setela...
# 9  dramatis denis bouanga mencetak gol telat di i...

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweets  200 non-null    object
#  1   step01  200 non-null    object
# dtypes: object(2)
# memory usage: 3.2+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 163 to 163
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweets  1 non-null      object
#  1   step01  1 non-null      object
# dtypes: object(2)
# memory usage: 24.0+ bytes

# %%
df_hapus.head()
# Out:
#                         Tweets    step01
# 163  💜 https://t.co/mcU6P9Bk50  comcupbk

# %%
df_new = df[~df.isin(df_hapus)].dropna()

df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweets  199 non-null    object
#  1   step01  199 non-null    object
# dtypes: object(2)
# memory usage: 4.7+ KB

# %%
df_new
# Out:
#                                                 Tweets  \
# 0    Napoli masih belum ada lawan, Barca rebut posi...
# 1    Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2    Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3    Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4    Sempat surut pada musim lalu, Christophe Galti...
# ..                                                 ...
# 195  @JCIndonesia Tetep optimis! 🙌 https://t.co/2cm...
# 196  Wake me up when September ends ~ 🎶 \n\nMonza b...
# 197  Kuda Hitam LaLiga musim ini? 🐎 Athletic Bilbao...
# 198  Juventus saat ini sedang krisis. Menurut asist...
# 199  Supersub pembungkam Juventus 🤐 Masuk pada meni...
#
#                                                 step01
# 0    napoli masih belum ada lawan barca rebut posis...
# 1    top skorer liga cleansheet liga terbanyak punc...
# 2    salah satu striker terbaik pada masanya strike...
# 3    monza habisi sampdoria gol gol dari pessina ca...
# 4    sempat surut pada musim lalu christophe galtie...
# ..                                                 ...
# 195              jcindonesia tetep optimis cocmfvrkool
# 196  wake me up when september ends monza beri keju...
# 197  kuda hitam laliga musim ini athletic bilbao da...
# 198  juventus saat ini sedang krisis menurut asiste...
# 199  supersub pembungkam juventus masuk pada menit ...
#
# [199 rows x 2 columns]

# %% [markdown]
# ## Normalisasi Kata - Kata Slang

# %%
import nltk
import swifter
from nltk.tokenize import word_tokenize

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head()
# Out:
#                                               Tweets  \
# 0  Napoli masih belum ada lawan, Barca rebut posi...
# 1  Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2  Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3  Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4  Sempat surut pada musim lalu, Christophe Galti...
#
#                                               step01  \
# 0  napoli masih belum ada lawan barca rebut posis...
# 1  top skorer liga cleansheet liga terbanyak punc...
# 2  salah satu striker terbaik pada masanya strike...
# 3  monza habisi sampdoria gol gol dari pessina ca...
# 4  sempat surut pada musim lalu christophe galtie...
#
#                                               tokens
# 0  [napoli, masih, belum, ada, lawan, barca, rebu...
# 1  [top, skorer, liga, cleansheet, liga, terbanya...
# 2  [salah, satu, striker, terbaik, pada, masanya,...
# 3  [monza, habisi, sampdoria, gol, gol, dari, pes...
# 4  [sempat, surut, pada, musim, lalu, christophe,...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

df_new.head()
# Out:
#                                               Tweets  \
# 0  Napoli masih belum ada lawan, Barca rebut posi...
# 1  Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2  Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3  Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4  Sempat surut pada musim lalu, Christophe Galti...
#
#                                               step01  \
# 0  napoli masih belum ada lawan barca rebut posis...
# 1  top skorer liga cleansheet liga terbanyak punc...
# 2  salah satu striker terbaik pada masanya strike...
# 3  monza habisi sampdoria gol gol dari pessina ca...
# 4  sempat surut pada musim lalu christophe galtie...
#
#                                               tokens  \
# 0  [napoli, masih, belum, ada, lawan, barca, rebu...
# 1  [top, skorer, liga, cleansheet, liga, terbanya...
# 2  [salah, satu, striker, terbaik, pada, masanya,...
# 3  [monza, habisi, sampdoria, gol, gol, dari, pes...
# 4  [sempat, surut, pada, musim, lalu, christophe,...
#
#                                         final_tokens  \
# 0  [napoli, masih, belum, ada, lawan, barca, rebu...
# 1  [top, skorer, liga, cleansheet, liga, terbanya...
# 2  [salah, satu, striker, terbaik, pada, masanya,...
# 3  [monza, habisi, sampdoria, gol, gol, dari, pes...
# 4  [sempat, surut, pada, musim, lalu, christophe,...
#
#                                               step02
# 0  napoli masih belum ada lawan barca rebut posis...
# 1  top skorer liga cleansheet liga terbanyak punc...
# 2  salah satu striker terbaik pada masanya strike...
# 3  monza habisi sampdoria gol gol dari pessina ca...
# 4  sempat surut pada musim lalu christophe galtie...

# %% [markdown]
# ## Simpan Clean Dataset

# %%
df_new.to_csv('clean_datasetbein.csv',sep=",")

# %% [markdown]
# ## Stemming Sastrawi

# %%
dataset = pd.read_csv('clean_datasetbein.csv')

dataset.head()
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Napoli masih belum ada lawan, Barca rebut posi...
# 1           1  Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2           2  Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3           3  Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4           4  Sempat surut pada musim lalu, Christophe Galti...
#
#                                               step01  \
# 0  napoli masih belum ada lawan barca rebut posis...
# 1  top skorer liga cleansheet liga terbanyak punc...
# 2  salah satu striker terbaik pada masanya strike...
# 3  monza habisi sampdoria gol gol dari pessina ca...
# 4  sempat surut pada musim lalu christophe galtie...
#
#                                               tokens  \
# 0  ['napoli', 'masih', 'belum', 'ada', 'lawan', '...
# 1  ['top', 'skorer', 'liga', 'cleansheet', 'liga'...
# 2  ['salah', 'satu', 'striker', 'terbaik', 'pada'...
# 3  ['monza', 'habisi', 'sampdoria', 'gol', 'gol',...
# 4  ['sempat', 'surut', 'pada', 'musim', 'lalu', '...
#
#                                         final_tokens  \
# 0  ['napoli', 'masih', 'belum', 'ada', 'lawan', '...
# 1  ['top', 'skorer', 'liga', 'cleansheet', 'liga'...
# 2  ['salah', 'satu', 'striker', 'terbaik', 'pada'...
# 3  ['monza', 'habisi', 'sampdoria', 'gol', 'gol',...
# 4  ['sempat', 'surut', 'pada', 'musim', 'lalu', '...
#
#                                               step02
# 0  napoli masih belum ada lawan barca rebut posis...
# 1  top skorer liga cleansheet liga terbanyak punc...
# 2  salah satu striker terbaik pada masanya strike...
# 3  monza habisi sampdoria gol gol dari pessina ca...
# 4  sempat surut pada musim lalu christophe galtie...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
 
factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang','yg']
 
# Tambahkan Stopword Baru
data = factory.get_stop_words()+more_stopword

stopwords_sastrawi = factory.create_stop_word_remover()

dictionary = ArrayDictionary(data)
str_stopwords = StopWordRemover(dictionary)

# %%
dataset['finalText_str'] = dataset['step02'].apply(str)

# %%
i=0
final_string = []
s = ""
for sentence in dataset["finalText_str"].values:
    filteredSentence = []
    EachReviewText = ""
    st = str_stopwords.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
dataset.loc[:, ('ProcessedText')] = final_string

# %%
dataset
# Out:
#      Unnamed: 0                                             Tweets  \
# 0             0  Napoli masih belum ada lawan, Barca rebut posi...
# 1             1  Top skorer liga ✅\nCleansheet liga terbanyak ✅...
# 2             2  Salah satu striker terbaik pada masanya 💥⚽\n\n...
# 3             3  Monza habisi Sampdoria 💥 Gol-gol dari Pessina,...
# 4             4  Sempat surut pada musim lalu, Christophe Galti...
# ..          ...                                                ...
# 194         195  @JCIndonesia Tetep optimis! 🙌 https://t.co/2cm...
# 195         196  Wake me up when September ends ~ 🎶 \n\nMonza b...
# 196         197  Kuda Hitam LaLiga musim ini? 🐎 Athletic Bilbao...
# 197         198  Juventus saat ini sedang krisis. Menurut asist...
# 198         199  Supersub pembungkam Juventus 🤐 Masuk pada meni...
#
#                                                 step01  \
# 0    napoli masih belum ada lawan barca rebut posis...
# 1    top skorer liga cleansheet liga terbanyak punc...
# 2    salah satu striker terbaik pada masanya strike...
# 3    monza habisi sampdoria gol gol dari pessina ca...
# 4    sempat surut pada musim lalu christophe galtie...
# ..                                                 ...
# 194              jcindonesia tetep optimis cocmfvrkool
# 195  wake me up when september ends monza beri keju...
# 196  kuda hitam laliga musim ini athletic bilbao da...
# 197  juventus saat ini sedang krisis menurut asiste...
# 198  supersub pembungkam juventus masuk pada menit ...
#
#                                                 tokens  \
# 0    ['napoli', 'masih', 'belum', 'ada', 'lawan', '...
# 1    ['top', 'skorer', 'liga', 'cleansheet', 'liga'...
# 2    ['salah', 'satu', 'striker', 'terbaik', 'pada'...
# 3    ['monza', 'habisi', 'sampdoria', 'gol', 'gol',...
# 4    ['sempat', 'surut', 'pada', 'musim', 'lalu', '...
# ..                                                 ...
# 194  ['jcindonesia', 'tetep', 'optimis', 'cocmfvrko...
# 195  ['wake', 'me', 'up', 'when', 'september', 'end...
# 196  ['kuda', 'hitam', 'laliga', 'musim', 'ini', 'a...
# 197  ['juventus', 'saat', 'ini', 'sedang', 'krisis'...
# 198  ['supersub', 'pembungkam', 'juventus', 'masuk'...
#
#                                           final_tokens  \
# 0    ['napoli', 'masih', 'belum', 'ada', 'lawan', '...
# 1    ['top', 'skorer', 'liga', 'cleansheet', 'liga'...
# 2    ['salah', 'satu', 'striker', 'terbaik', 'pada'...
# 3    ['monza', 'habisi', 'sampdoria', 'gol', 'gol',...
# 4    ['sempat', 'surut', 'pada', 'musim', 'lalu', '...
# ..                                                 ...
# 194  ['jcindonesia', 'tetep', 'optimis', 'cocmfvrko...
# 195  ['wake', 'me', 'up', 'when', 'september', 'end...
# 196  ['kuda', 'hitam', 'laliga', 'musim', 'ini', 'a...
# 197  ['juventus', 'saat', 'ini', 'sedang', 'krisis'...
# 198  ['supersub', 'pembungkam', 'juventus', 'masuk'...
#
#                                                 step02  \
# 0    napoli masih belum ada lawan barca rebut posis...
# 1    top skorer liga cleansheet liga terbanyak punc...
# 2    salah satu striker terbaik pada masanya strike...
# 3    monza habisi sampdoria gol gol dari pessina ca...
# 4    sempat surut pada musim lalu christophe galtie...
# ..                                                 ...
# 194              jcindonesia tetep optimis cocmfvrkool
# 195  wake me up when september ends monza beri keju...
# 196  kuda hitam laliga musim ini athletic bilbao da...
# 197  juventus saat ini sedang krisis menurut asiste...
# 198  supersub pembungkam juventus masuk pada menit ...
#
#                                          finalText_str  \
# 0    napoli masih belum ada lawan barca rebut posis...
# 1    top skorer liga cleansheet liga terbanyak punc...
# 2    salah satu striker terbaik pada masanya strike...
# 3    monza habisi sampdoria gol gol dari pessina ca...
# 4    sempat surut pada musim lalu christophe galtie...
# ..                                                 ...
# 194              jcindonesia tetep optimis cocmfvrkool
# 195  wake me up when september ends monza beri keju...
# 196  kuda hitam laliga musim ini athletic bilbao da...
# 197  juventus saat ini sedang krisis menurut asiste...
# 198  supersub pembungkam juventus masuk pada menit ...
#
#                                          ProcessedText
# 0    napoli belum lawan barca rebut posisi puncak t...
# 1    top skorer liga cleansheet liga banyak puncak ...
# 2    salah satu striker baik masa striker inter mia...
# 3    monza habis sampdoria gol gol pessina caprari ...
# 4    sempat surut musim lalu christophe galtier yak...
# ..                                                 ...
# 194              jcindonesia tetep optimis cocmfvrkool
# 195  wake me up when september ends monza beri keju...
# 196  kuda hitam laliga musim athletic bilbao lawan ...
# 197  juventus ini sedang krisis asisten massimilian...
# 198  supersub bungkam juventus masuk menit christia...
#
# [199 rows x 8 columns]

# %%
dataset.to_csv('clean_datasetbein_stem.csv',sep=';')
