# %% [markdown]
# ## UJIAN TENGAH SEMESTER MATA KULIAH ANALITIKA MEDIA SOSIAL
#
# Alief Rachmandias Darmawan - A12.2020.06416 - A12.6501
#
# Eksperimen Only Bigrams

# %% [markdown]
# ## Pemanggilan Library

# %%
import pandas as pd
import time
import tweepy
import numpy as np
import swifter

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_narasi_fixlabel.csv', sep=';')

df.head()
# Out:
#    Column1  Unnamed: 0                                             Tweets  \
# 0        0           0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...
# 1        1           1  Soalnya, RKUHP yang baru berisi pasal perzinah...
# 2        2           2  #Semuabisakena. Inget, kan, sama kampanye peno...
# 3        3           3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...
# 4        4           4  Semoga aja amunisi Kominfo bisa efektif buat n...
#
#    Label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Column1     100 non-null    int64
#  1   Unnamed: 0  100 non-null    int64
#  2   Tweets      100 non-null    object
#  3   Label       100 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ## Tahapan Pre Processing

# %%
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Proses Penataan Data

# %% [markdown]
# - Disini saya menggunakan ekpharasis

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %% [markdown]
# - Memanggil ekhparasis

# %%
def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return re.sub(r'https?:\/\/\S*', '', text, flags=re.MULTILINE)

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text) 

def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# - Memulai proses pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

df.head(10)
# Out:
#    Column1  Unnamed: 0                                             Tweets  \
# 0        0           0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...
# 1        1           1  Soalnya, RKUHP yang baru berisi pasal perzinah...
# 2        2           2  #Semuabisakena. Inget, kan, sama kampanye peno...
# 3        3           3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...
# 4        4           4  Semoga aja amunisi Kominfo bisa efektif buat n...
# 5        5           5  Menurut LBH Bogor, Irwansyah, pemerintah Kota ...
# 6        6           6  “Harapan saya untuk Arema, yang meninggal dan ...
# 7        7           7  Kayaknya di luaran sana gampang banget ya buat...
# 8        8           8  Izin dulu buat pake lagunya ke .Feast bisa kal...
# 9        9           9  Apa sih etilen glikol dan dietilen glikol yang...
#
#    Label                                             step01
# 0      1  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1      1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2      1  inget kan sama kampanye penolakan rancangan un...
# 3      1  gugatannya udah kalah selanjutnya pak jokowi d...
# 4      0  semoga aja amunisi kominfo bisa efektif buat n...
# 5      1  menurut lbh bogor irwansyah pemerintah kota bo...
# 6      0  harapan saya untuk arema yang meninggal dan ja...
# 7      1  kayaknya di luaran sana gampang banget ya buat...
# 8      1  izin dulu buat pake lagunya ke feast bisa kali...
# 9      0  apa sih etilen glikol dan dietilen glikol yang...

# %%
df = df.drop(['Column1'], axis=1)

df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head(10)
# Out:
#                                               Tweets  Label  \
# 0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...      1
# 1  Soalnya, RKUHP yang baru berisi pasal perzinah...      1
# 2  #Semuabisakena. Inget, kan, sama kampanye peno...      1
# 3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...      1
# 4  Semoga aja amunisi Kominfo bisa efektif buat n...      0
# 5  Menurut LBH Bogor, Irwansyah, pemerintah Kota ...      1
# 6  “Harapan saya untuk Arema, yang meninggal dan ...      0
# 7  Kayaknya di luaran sana gampang banget ya buat...      1
# 8  Izin dulu buat pake lagunya ke .Feast bisa kal...      1
# 9  Apa sih etilen glikol dan dietilen glikol yang...      0
#
#                                               step01
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 4  semoga aja amunisi kominfo bisa efektif buat n...
# 5  menurut lbh bogor irwansyah pemerintah kota bo...
# 6  harapan saya untuk arema yang meninggal dan ja...
# 7  kayaknya di luaran sana gampang banget ya buat...
# 8  izin dulu buat pake lagunya ke feast bisa kali...
# 9  apa sih etilen glikol dan dietilen glikol yang...

# %% [markdown]
# ## Hapus Data Kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweets  100 non-null    object
#  1   Label   100 non-null    int64
#  2   step01  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweets  0 non-null      object
#  1   Label   0 non-null      int64
#  2   step01  0 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
df_hapus.head()
# Out:
# Empty DataFrame
# Columns: [Tweets, Label, step01]
# Index: []

# %%
df_new = df[~df.isin(df_hapus)].dropna()

df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tweets  100 non-null    object
#  1   Label   100 non-null    int64
#  2   step01  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df_new
# Out:
#                                                Tweets  Label  \
# 0   Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...      1
# 1   Soalnya, RKUHP yang baru berisi pasal perzinah...      1
# 2   #Semuabisakena. Inget, kan, sama kampanye peno...      1
# 3   Gugatannya udah kalah. Selanjutnya, Pak Jokowi...      1
# 4   Semoga aja amunisi Kominfo bisa efektif buat n...      0
# ..                                                ...    ...
# 95  Kenapa sih maksa banget jadwal pertandingan di...      1
# 96  Kelima terdakwa dalam kasus pembunuhan Yosua t...      1
# 97  Lembaga Perlindungan Saksi dan Korban (LPSK) m...      1
# 98  Eliezer beserta Ferdy Sambo, Putri Candrawathi...      1
# 99  Sidang perdana Bharada Richard Eliezer Pudihan...      1
#
#                                                step01
# 0   ketua dpp phri dki jakarta sutrisno iwantono b...
# 1   soalnya rkuhp yang baru berisi pasal perzinaha...
# 2   inget kan sama kampanye penolakan rancangan un...
# 3   gugatannya udah kalah selanjutnya pak jokowi d...
# 4   semoga aja amunisi kominfo bisa efektif buat n...
# ..                                                ...
# 95  kenapa sih maksa banget jadwal pertandingan di...
# 96  kelima terdakwa dalam kasus pembunuhan yosua t...
# 97  lembaga perlindungan saksi dan korban lpsk men...
# 98  eliezer beserta ferdy sambo putri candrawathi ...
# 99  sidang perdana bharada richard eliezer pudihan...
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Normalisasi Kata Slang

# %%
import nltk
import swifter
from nltk.tokenize import word_tokenize

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head()
# Out:
#                                               Tweets  Label  \
# 0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...      1
# 1  Soalnya, RKUHP yang baru berisi pasal perzinah...      1
# 2  #Semuabisakena. Inget, kan, sama kampanye peno...      1
# 3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...      1
# 4  Semoga aja amunisi Kominfo bisa efektif buat n...      0
#
#                                               step01  \
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 4  semoga aja amunisi kominfo bisa efektif buat n...
#
#                                               tokens
# 0  [ketua, dpp, phri, dki, jakarta, sutrisno, iwa...
# 1  [soalnya, rkuhp, yang, baru, berisi, pasal, pe...
# 2  [inget, kan, sama, kampanye, penolakan, rancan...
# 3  [gugatannya, udah, kalah, selanjutnya, pak, jo...
# 4  [semoga, aja, amunisi, kominfo, bisa, efektif,...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

df_new.head()
# Out:
#                                               Tweets  Label  \
# 0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...      1
# 1  Soalnya, RKUHP yang baru berisi pasal perzinah...      1
# 2  #Semuabisakena. Inget, kan, sama kampanye peno...      1
# 3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...      1
# 4  Semoga aja amunisi Kominfo bisa efektif buat n...      0
#
#                                               step01  \
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 4  semoga aja amunisi kominfo bisa efektif buat n...
#
#                                               tokens  \
# 0  [ketua, dpp, phri, dki, jakarta, sutrisno, iwa...
# 1  [soalnya, rkuhp, yang, baru, berisi, pasal, pe...
# 2  [inget, kan, sama, kampanye, penolakan, rancan...
# 3  [gugatannya, udah, kalah, selanjutnya, pak, jo...
# 4  [semoga, aja, amunisi, kominfo, bisa, efektif,...
#
#                                         final_tokens  \
# 0  [ketua, dpp, phri, dki, jakarta, sutrisno, iwa...
# 1  [soalnya, rkuhp, yang, baru, berisi, pasal, pe...
# 2  [inget, kan, sama, kampanye, penolakan, rancan...
# 3  [gugatannya, udah, kalah, selanjutnya, pak, jo...
# 4  [semoga, aja, amunisi, kominfo, bisa, efektif,...
#
#                                               step02
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 4  semoga aja amunisi kominfo bisa efektif buat n...

# %% [markdown]
# ## Simpan Clean Dataset

# %%
df_new.to_csv('clean_dataset_narasi.csv',sep=",")

# %% [markdown]
# ## Stemming menggunakan Sastrawi

# %%
dataset = pd.read_csv('clean_dataset_narasi.csv')

dataset.head()
# Out:
#    Unnamed: 0                                             Tweets  Label  \
# 0           0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...      1
# 1           1  Soalnya, RKUHP yang baru berisi pasal perzinah...      1
# 2           2  #Semuabisakena. Inget, kan, sama kampanye peno...      1
# 3           3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...      1
# 4           4  Semoga aja amunisi Kominfo bisa efektif buat n...      0
#
#                                               step01  \
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 4  semoga aja amunisi kominfo bisa efektif buat n...
#
#                                               tokens  \
# 0  ['ketua', 'dpp', 'phri', 'dki', 'jakarta', 'su...
# 1  ['soalnya', 'rkuhp', 'yang', 'baru', 'berisi',...
# 2  ['inget', 'kan', 'sama', 'kampanye', 'penolaka...
# 3  ['gugatannya', 'udah', 'kalah', 'selanjutnya',...
# 4  ['semoga', 'aja', 'amunisi', 'kominfo', 'bisa'...
#
#                                         final_tokens  \
# 0  ['ketua', 'dpp', 'phri', 'dki', 'jakarta', 'su...
# 1  ['soalnya', 'rkuhp', 'yang', 'baru', 'berisi',...
# 2  ['inget', 'kan', 'sama', 'kampanye', 'penolaka...
# 3  ['gugatannya', 'udah', 'kalah', 'selanjutnya',...
# 4  ['semoga', 'aja', 'amunisi', 'kominfo', 'bisa'...
#
#                                               step02
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 4  semoga aja amunisi kominfo bisa efektif buat n...

# %% [markdown]
# ## Load Sastrawi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
 
factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang','yg']
 
# Tambahkan Stopword Baru
data = factory.get_stop_words()+more_stopword

stopwords_sastrawi = factory.create_stop_word_remover()

dictionary = ArrayDictionary(data)
str_stopwords = StopWordRemover(dictionary)

# %%
dataset['finalText_str'] = dataset['step02'].apply(str)

# %%
i=0
final_string = []
s = ""
for sentence in dataset["finalText_str"].values:
    filteredSentence = []
    EachReviewText = ""
    st = str_stopwords.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
dataset.loc[:, ('ProcessedText')] = final_string

# %%
dataset
# Out:
#     Unnamed: 0                                             Tweets  Label  \
# 0            0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...      1
# 1            1  Soalnya, RKUHP yang baru berisi pasal perzinah...      1
# 2            2  #Semuabisakena. Inget, kan, sama kampanye peno...      1
# 3            3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...      1
# 4            4  Semoga aja amunisi Kominfo bisa efektif buat n...      0
# ..         ...                                                ...    ...
# 95          95  Kenapa sih maksa banget jadwal pertandingan di...      1
# 96          96  Kelima terdakwa dalam kasus pembunuhan Yosua t...      1
# 97          97  Lembaga Perlindungan Saksi dan Korban (LPSK) m...      1
# 98          98  Eliezer beserta Ferdy Sambo, Putri Candrawathi...      1
# 99          99  Sidang perdana Bharada Richard Eliezer Pudihan...      1
#
#                                                step01  \
# 0   ketua dpp phri dki jakarta sutrisno iwantono b...
# 1   soalnya rkuhp yang baru berisi pasal perzinaha...
# 2   inget kan sama kampanye penolakan rancangan un...
# 3   gugatannya udah kalah selanjutnya pak jokowi d...
# 4   semoga aja amunisi kominfo bisa efektif buat n...
# ..                                                ...
# 95  kenapa sih maksa banget jadwal pertandingan di...
# 96  kelima terdakwa dalam kasus pembunuhan yosua t...
# 97  lembaga perlindungan saksi dan korban lpsk men...
# 98  eliezer beserta ferdy sambo putri candrawathi ...
# 99  sidang perdana bharada richard eliezer pudihan...
#
#                                                tokens  \
# 0   ['ketua', 'dpp', 'phri', 'dki', 'jakarta', 'su...
# 1   ['soalnya', 'rkuhp', 'yang', 'baru', 'berisi',...
# 2   ['inget', 'kan', 'sama', 'kampanye', 'penolaka...
# 3   ['gugatannya', 'udah', 'kalah', 'selanjutnya',...
# 4   ['semoga', 'aja', 'amunisi', 'kominfo', 'bisa'...
# ..                                                ...
# 95  ['kenapa', 'sih', 'maksa', 'banget', 'jadwal',...
# 96  ['kelima', 'terdakwa', 'dalam', 'kasus', 'pemb...
# 97  ['lembaga', 'perlindungan', 'saksi', 'dan', 'k...
# 98  ['eliezer', 'beserta', 'ferdy', 'sambo', 'putr...
# 99  ['sidang', 'perdana', 'bharada', 'richard', 'e...
#
#                                          final_tokens  \
# 0   ['ketua', 'dpp', 'phri', 'dki', 'jakarta', 'su...
# 1   ['soalnya', 'rkuhp', 'yang', 'baru', 'berisi',...
# 2   ['inget', 'kan', 'sama', 'kampanye', 'penolaka...
# 3   ['gugatannya', 'udah', 'kalah', 'selanjutnya',...
# 4   ['semoga', 'aja', 'amunisi', 'kominfo', 'bisa'...
# ..                                                ...
# 95  ['kenapa', 'sih', 'maksa', 'banget', 'jadwal',...
# 96  ['kelima', 'terdakwa', 'dalam', 'kasus', 'pemb...
# 97  ['lembaga', 'perlindungan', 'saksi', 'dan', 'k...
# 98  ['eliezer', 'beserta', 'ferdy', 'sambo', 'putr...
# 99  ['sidang', 'perdana', 'bharada', 'richard', 'e...
#
#                                                step02  \
# 0   ketua dpp phri dki jakarta sutrisno iwantono b...
# 1   soalnya rkuhp yang baru berisi pasal perzinaha...
# 2   inget kan sama kampanye penolakan rancangan un...
# 3   gugatannya udah kalah selanjutnya pak jokowi d...
# 4   semoga aja amunisi kominfo bisa efektif buat n...
# ..                                                ...
# 95  kenapa sih maksa banget jadwal pertandingan di...
# 96  kelima terdakwa dalam kasus pembunuhan yosua t...
# 97  lembaga perlindungan saksi dan korban lpsk men...
# 98  eliezer beserta ferdy sambo putri candrawathi ...
# 99  sidang perdana bharada richard eliezer pudihan...
#
#                                         finalText_str  \
# 0   ketua dpp phri dki jakarta sutrisno iwantono b...
# 1   soalnya rkuhp yang baru berisi pasal perzinaha...
# 2   inget kan sama kampanye penolakan rancangan un...
# 3   gugatannya udah kalah selanjutnya pak jokowi d...
# 4   semoga aja amunisi kominfo bisa efektif buat n...
# ..                                                ...
# 95  kenapa sih maksa banget jadwal pertandingan di...
# 96  kelima terdakwa dalam kasus pembunuhan yosua t...
# 97  lembaga perlindungan saksi dan korban lpsk men...
# 98  eliezer beserta ferdy sambo putri candrawathi ...
# 99  sidang perdana bharada richard eliezer pudihan...
#
#                                         ProcessedText
# 0   ketua dpp phri dki jakarta sutrisno iwantono b...
# 1   soal rkuhp baru isi pasal perzinahan anggap ru...
# 2   inget kan sama kampanye tolak rancang undang u...
# 3   gugat udah kalah lanjut pak jokowi para menter...
# 4   moga aja amunisi kominfo efektif buat ngeberan...
# ..                                                ...
# 95  sih maksa banget jadwal tanding kanjuruhan ada...
# 96  lima dakwa kasus bunuh yosua sebut dakwa langg...
# 97  lembaga lindung saksi korban lpsk kabul mohon ...
# 98  eliezer serta ferdy sambo putri candrawathi ri...
# 99  sidang perdana bharada richard eliezer pudihan...
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Menyimpan dataset baru

# %%
dataset.to_csv('clean_dataset_narasi_stem.csv',sep=',')

# %% [markdown]
# Pada tahap ini data sudah bersih, setelah ini lanjut ke tahapan machine learning

# %% [markdown]
# ## Proses Modeling

# %% [markdown]
# - Dibagi menjadi feature dan label

# %%
dataset_feature = dataset['ProcessedText']

# %%
dataset_feature.head(5)
# Out:
# 0    ketua dpp phri dki jakarta sutrisno iwantono b...
# 1    soal rkuhp baru isi pasal perzinahan anggap ru...
# 2    inget kan sama kampanye tolak rancang undang u...
# 3    gugat udah kalah lanjut pak jokowi para menter...
# 4    moga aja amunisi kominfo efektif buat ngeberan...
# Name: ProcessedText, dtype: object

# %%
dataset_label = dataset['Label']

# %%
dataset_label.head(5)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Label, dtype: int64

# %% [markdown]
# ## Cek Distribusi Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset_label.value_counts()
# Out:
# 0    59
# 1    41
# Name: Label, dtype: int64

# %%
dataset_label.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 0    59.0%
# 1    41.0%
# Name: Label, dtype: object

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Bisa dilihat pada hasil proses distibusi data pada dataset yang saya gunakan, bahwa tweets yang bertema Politik (kode = 1) sebanyak 41 (41.0%). Sedangkan tweets yang bertema Non Politik (kode = 0) sebanyak 59 (59.0%).

# %% [markdown]
# ## Fitur Ekstraksi Menggunakan TF-IDF

# %% [markdown]
# ## Cek Label (Parameter Politik (1) dan Non Politik (0) )

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
politik_reviews = dataset[(dataset["Label"] == 1)]
npolitik_reviews = dataset[(dataset["Label"] == 0)]

# %% [markdown]
# ## Cek Label Politik Reviews

# %%
politik_reviews.head()
# Out:
#    Unnamed: 0                                             Tweets  Label  \
# 0           0  Ketua DPP PHRI DKI Jakarta Sutrisno Iwantono b...      1
# 1           1  Soalnya, RKUHP yang baru berisi pasal perzinah...      1
# 2           2  #Semuabisakena. Inget, kan, sama kampanye peno...      1
# 3           3  Gugatannya udah kalah. Selanjutnya, Pak Jokowi...      1
# 5           5  Menurut LBH Bogor, Irwansyah, pemerintah Kota ...      1
#
#                                               step01  \
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 5  menurut lbh bogor irwansyah pemerintah kota bo...
#
#                                               tokens  \
# 0  ['ketua', 'dpp', 'phri', 'dki', 'jakarta', 'su...
# 1  ['soalnya', 'rkuhp', 'yang', 'baru', 'berisi',...
# 2  ['inget', 'kan', 'sama', 'kampanye', 'penolaka...
# 3  ['gugatannya', 'udah', 'kalah', 'selanjutnya',...
# 5  ['menurut', 'lbh', 'bogor', 'irwansyah', 'peme...
#
#                                         final_tokens  \
# 0  ['ketua', 'dpp', 'phri', 'dki', 'jakarta', 'su...
# 1  ['soalnya', 'rkuhp', 'yang', 'baru', 'berisi',...
# 2  ['inget', 'kan', 'sama', 'kampanye', 'penolaka...
# 3  ['gugatannya', 'udah', 'kalah', 'selanjutnya',...
# 5  ['menurut', 'lbh', 'bogor', 'irwansyah', 'peme...
#
#                                               step02  \
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 5  menurut lbh bogor irwansyah pemerintah kota bo...
#
#                                        finalText_str  \
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soalnya rkuhp yang baru berisi pasal perzinaha...
# 2  inget kan sama kampanye penolakan rancangan un...
# 3  gugatannya udah kalah selanjutnya pak jokowi d...
# 5  menurut lbh bogor irwansyah pemerintah kota bo...
#
#                                        ProcessedText
# 0  ketua dpp phri dki jakarta sutrisno iwantono b...
# 1  soal rkuhp baru isi pasal perzinahan anggap ru...
# 2  inget kan sama kampanye tolak rancang undang u...
# 3  gugat udah kalah lanjut pak jokowi para menter...
# 5  lbh bogor irwansyah perintah kota bogor gugat ...

# %%
Politik_tf_idf_vect = TfidfVectorizer(ngram_range=(2,2))
Politik_tf_idf = Politik_tf_idf_vect.fit_transform(politik_reviews["ProcessedText"].values)

# %%
Politik_tf_idf.shape
# Out:
# (41, 454)

# %%
features = Politik_tf_idf_vect.get_feature_names()

idfValues = Politik_tf_idf_vect.idf_

d = dict(zip(features, 9 - idfValues))

sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

for i in range(200):
    print(sortedDict[i])
# Out:
# ('richard eliezer', 6.2082405307719455)
# ('ferdy sambo', 6.0540898509446865)
# ('narasi daily', 5.871768294150732)
# ('sidang perdana', 5.871768294150732)
# ('brigadir yosua', 5.648624742836523)
# ('kasus bunuh', 5.648624742836523)
# ('obstruction of', 5.648624742836523)
# ('of justice', 5.648624742836523)
# ('aju eksepsi', 5.360942670384741)
# ('atas dakwa', 5.360942670384741)
# ('berat atas', 5.360942670384741)
# ('bharada richard', 5.360942670384741)
# ('bunuh brigadir', 5.360942670384741)
# ('bunuh rencana', 5.360942670384741)
# ('eliezer pudihang', 5.360942670384741)
# ('enggak aju', 5.360942670384741)
# ('hendra kurniawan', 5.360942670384741)
# ('nota berat', 5.360942670384741)
# ('pak jokowi', 5.360942670384741)
# ('pudihang lumiu', 5.360942670384741)
# ('putri candrawathi', 5.360942670384741)
# ('tak aju', 5.360942670384741)
# ('acara eliezer', 4.955477562276577)
# ('acara hendra', 4.955477562276577)
# ('acara richard', 4.955477562276577)
# ('ada agenda', 4.955477562276577)
# ('ada malam', 4.955477562276577)
# ('adil negeri', 4.955477562276577)
# ('agenda moga', 4.955477562276577)
# ('agus nur', 4.955477562276577)
# ('ajak pak', 4.955477562276577)
# ('aju ekseps', 4.955477562276577)
# ('aju nota', 4.955477562276577)
# ('akbp ferdy', 4.955477562276577)
# ('akhir ambil', 4.955477562276577)
# ('akhir reka', 4.955477562276577)
# ('aku kalau', 4.955477562276577)
# ('aku sesal', 4.955477562276577)
# ('aku yerusalem', 4.955477562276577)
# ('alasaannya iwan', 4.955477562276577)
# ('alias bharada', 4.955477562276577)
# ('amplop isi', 4.955477562276577)
# ('anggap lalai', 4.955477562276577)
# ('anggap rugi', 4.955477562276577)
# ('anggota polri', 4.955477562276577)
# ('anulir bijak', 4.955477562276577)
# ('apa nih', 4.955477562276577)
# ('apalagi buat', 4.955477562276577)
# ('arab saudi', 4.955477562276577)
# ('arti anulir', 4.955477562276577)
# ('arti bakal', 4.955477562276577)
# ('as sama', 4.955477562276577)
# ('atas dakw', 4.955477562276577)
# ('atas kasus', 4.955477562276577)
# ('australia scott', 4.955477562276577)
# ('australia tadi', 4.955477562276577)
# ('baca acara', 4.955477562276577)
# ('baca deh', 4.955477562276577)
# ('bagi jadi', 4.955477562276577)
# ('baju sono', 4.955477562276577)
# ('bakal buat', 4.955477562276577)
# ('bakal susah', 4.955477562276577)
# ('balik aku', 4.955477562276577)
# ('banget buat', 4.955477562276577)
# ('banget denger', 4.955477562276577)
# ('banget jadwal', 4.955477562276577)
# ('barang bukti', 4.955477562276577)
# ('bareng fifa', 4.955477562276577)
# ('baru isi', 4.955477562276577)
# ('bebas pakar', 4.955477562276577)
# ('bechi bilang', 4.955477562276577)
# ('beda ferdy', 4.955477562276577)
# ('beda gitu', 4.955477562276577)
# ('benar berapa', 4.955477562276577)
# ('berapa gantung', 4.955477562276577)
# ('berapa kali', 4.955477562276577)
# ('bersih ckckck', 4.955477562276577)
# ('besar agus', 4.955477562276577)
# ('besar iran', 4.955477562276577)
# ('bharada eliezer', 4.955477562276577)
# ('bharada kasus', 4.955477562276577)
# ('bharada pilih', 4.955477562276577)
# ('bijak mantan', 4.955477562276577)
# ('bilang bukan', 4.955477562276577)
# ('bilang sidang', 4.955477562276577)
# ('bilang tembak', 4.955477562276577)
# ('bilang tuntut', 4.955477562276577)
# ('bogor gugat', 4.955477562276577)
# ('bogor irwansyah', 4.955477562276577)
# ('bogor kota', 4.955477562276577)
# ('brigadir dic', 4.955477562276577)
# ('buat dakwa', 4.955477562276577)
# ('buat namun', 4.955477562276577)
# ('buat ngakuin', 4.955477562276577)
# ('buat pake', 4.955477562276577)
# ('buat perlu', 4.955477562276577)
# ('buka data', 4.955477562276577)
# ('bukan tak', 4.955477562276577)
# ('bukankah polri', 4.955477562276577)
# ('bukti langgar', 4.955477562276577)
# ('bule ada', 4.955477562276577)
# ('bunuh yosua', 4.955477562276577)
# ('candrawathi ngakunya', 4.955477562276577)
# ('candrawathi ricky', 4.955477562276577)
# ('cek datany', 4.955477562276577)
# ('cek video', 4.955477562276577)
# ('ckckck mudah', 4.955477562276577)
# ('collaborator da', 4.955477562276577)
# ('cuci baju', 4.955477562276577)
# ('cuci uang', 4.955477562276577)
# ('dakwa amplop', 4.955477562276577)
# ('dakwa disampaika', 4.955477562276577)
# ('dakwa jaksa', 4.955477562276577)
# ('dakwa kasus', 4.955477562276577)
# ('dakwa laku', 4.955477562276577)
# ('dakwa langgar', 4.955477562276577)
# ('dakwa sampai', 4.955477562276577)
# ('deh bakal', 4.955477562276577)
# ('deh hasil', 4.955477562276577)
# ('deh periksa', 4.955477562276577)
# ('denger resesi', 4.955477562276577)
# ('djuyamto bilang', 4.955477562276577)
# ('dki jakarta', 4.955477562276577)
# ('dpp phri', 4.955477562276577)
# ('dua majelis', 4.955477562276577)
# ('duga bunuh', 4.955477562276577)
# ('dulu buat', 4.955477562276577)
# ('dunia pernah', 4.955477562276577)
# ('duta besar', 4.955477562276577)
# ('ekonomi dunia', 4.955477562276577)
# ('eksepsi atas', 4.955477562276577)
# ('eksepsi ferdy', 4.955477562276577)
# ('eksepsi nota', 4.955477562276577)
# ('eliezer akhir', 4.955477562276577)
# ('eliezer aku', 4.955477562276577)
# ('eliezer enggak', 4.955477562276577)
# ('eliezer jadi', 4.955477562276577)
# ('eliezer laksana', 4.955477562276577)
# ('eliezer ronny', 4.955477562276577)
# ('eliezer serta', 4.955477562276577)
# ('emang berapa', 4.955477562276577)
# ('enam sangka', 4.955477562276577)
# ('enggak ajak', 4.955477562276577)
# ('enggak paham', 4.955477562276577)
# ('enggak sesuai', 4.955477562276577)
# ('enggak tunda', 4.955477562276577)
# ('fakta sidang', 4.955477562276577)
# ('familiar narasi', 4.955477562276577)
# ('fasilitas umum', 4.955477562276577)
# ('feast kali', 4.955477562276577)
# ('ferdy irawan', 4.955477562276577)
# ('fifa istana', 4.955477562276577)
# ('gampang banget', 4.955477562276577)
# ('ganti richard', 4.955477562276577)
# ('gantung as', 4.955477562276577)
# ('gimana cek', 4.955477562276577)
# ('gimana narasi', 4.955477562276577)
# ('gitu na', 4.955477562276577)
# ('gugat anggap', 4.955477562276577)
# ('gugat udah', 4.955477562276577)
# ('hadeh buka', 4.955477562276577)
# ('hak moral', 4.955477562276577)
# ('hakim sesi', 4.955477562276577)
# ('hal sadis', 4.955477562276577)
# ('hanya nyata', 4.955477562276577)
# ('hanya orang', 4.955477562276577)
# ('hari acara', 4.955477562276577)
# ('hari baca', 4.955477562276577)
# ('hari ganti', 4.955477562276577)
# ('hasil lapor', 4.955477562276577)
# ('hendra ferdy', 4.955477562276577)
# ('heu emang', 4.955477562276577)
# ('hijab informasi', 4.955477562276577)
# ('hilang tanding', 4.955477562276577)
# ('hotel narasi', 4.955477562276577)
# ('hukum pidana', 4.955477562276577)
# ('humas pn', 4.955477562276577)
# ('ibu kota', 4.955477562276577)
# ('industri pariwisata', 4.955477562276577)
# ('informasi akhir', 4.955477562276577)
# ('inget kan', 4.955477562276577)
# ('intimidasi deh', 4.955477562276577)
# ('intimidasi intimidasi', 4.955477562276577)
# ('iran seoul', 4.955477562276577)
# ('irawan bilang', 4.955477562276577)
# ('irwansyah perintah', 4.955477562276577)
# ('isi pasal', 4.955477562276577)
# ('isi uang', 4.955477562276577)
# ('israel sekarang', 4.955477562276577)
# ('israel tel', 4.955477562276577)
# ('istana alas', 4.955477562276577)
# ('iwan bule', 4.955477562276577)
# ('iwantono bilang', 4.955477562276577)
# ('izin dulu', 4.955477562276577)
# ('jabat beda', 4.955477562276577)
# ('jabat benar', 4.955477562276577)
# ('jabat humas', 4.955477562276577)
# ('jadi justice', 4.955477562276577)
# ('jadi sesi', 4.955477562276577)
# ('jadwal tanding', 4.955477562276577)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plot

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %% [markdown]
# ## Cek Label Non Politik

# %%
npolitik_reviews.head()
# Out:
#     Unnamed: 0                                             Tweets  Label  \
# 4            4  Semoga aja amunisi Kominfo bisa efektif buat n...      0
# 6            6  “Harapan saya untuk Arema, yang meninggal dan ...      0
# 9            9  Apa sih etilen glikol dan dietilen glikol yang...      0
# 10          10  Tidak cuma keluarga, Nanda, sahabat Revan pun ...      0
# 11          11  Dua hari sebelum peristiwa, Revan sudah berpam...      0
#
#                                                step01  \
# 4   semoga aja amunisi kominfo bisa efektif buat n...
# 6   harapan saya untuk arema yang meninggal dan ja...
# 9   apa sih etilen glikol dan dietilen glikol yang...
# 10  tidak cuma keluarga nanda sahabat revan pun me...
# 11  dua hari sebelum peristiwa revan sudah berpami...
#
#                                                tokens  \
# 4   ['semoga', 'aja', 'amunisi', 'kominfo', 'bisa'...
# 6   ['harapan', 'saya', 'untuk', 'arema', 'yang', ...
# 9   ['apa', 'sih', 'etilen', 'glikol', 'dan', 'die...
# 10  ['tidak', 'cuma', 'keluarga', 'nanda', 'sahaba...
# 11  ['dua', 'hari', 'sebelum', 'peristiwa', 'revan...
#
#                                          final_tokens  \
# 4   ['semoga', 'aja', 'amunisi', 'kominfo', 'bisa'...
# 6   ['harapan', 'saya', 'untuk', 'arema', 'yang', ...
# 9   ['apa', 'sih', 'etilen', 'glikol', 'dan', 'die...
# 10  ['tidak', 'cuma', 'keluarga', 'nanda', 'sahaba...
# 11  ['dua', 'hari', 'sebelum', 'peristiwa', 'revan...
#
#                                                step02  \
# 4   semoga aja amunisi kominfo bisa efektif buat n...
# 6   harapan saya untuk arema yang meninggal dan ja...
# 9   apa sih etilen glikol dan dietilen glikol yang...
# 10  tidak cuma keluarga nanda sahabat revan pun me...
# 11  dua hari sebelum peristiwa revan sudah berpami...
#
#                                         finalText_str  \
# 4   semoga aja amunisi kominfo bisa efektif buat n...
# 6   harapan saya untuk arema yang meninggal dan ja...
# 9   apa sih etilen glikol dan dietilen glikol yang...
# 10  tidak cuma keluarga nanda sahabat revan pun me...
# 11  dua hari sebelum peristiwa revan sudah berpami...
#
#                                         ProcessedText
# 4   moga aja amunisi kominfo efektif buat ngeberan...
# 6   harap untuk arema tinggal jadi korban suporter...
# 9   apa etilen glikol dietilen glikol sebab ratus ...
# 10  cuma keluarga nanda sahabat revan rasa amat hi...
# 11  hari peristiwa revan pamit ayah tonton langsun...

# %%
NPolitik_tf_idf_vect = TfidfVectorizer(ngram_range=(2,2))
NPolitik_tf_idf = NPolitik_tf_idf_vect.fit_transform(npolitik_reviews["ProcessedText"].values)

# %%
NPolitik_tf_idf.shape
# Out:
# (59, 638)

# %%
features = NPolitik_tf_idf_vect.get_feature_names()

idfValues = NPolitik_tf_idf_vect.idf_

d = dict(zip(features, 9 - idfValues))

sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

for i in range(200):
    print(sortedDict[i])
# Out:
# ('narasi daily', 6.2082405307719455)
# ('ginjal akut', 5.515093350212)
# ('gagal ginjal', 5.2919497988977895)
# ('peristiwa kanjuruhan', 5.2919497988977895)
# ('polres bintan', 5.2919497988977895)
# ('sepak bola', 5.2919497988977895)
# ('antar jemput', 5.00426772644601)
# ('capai orang', 5.00426772644601)
# ('dapat kasus', 5.00426772644601)
# ('it easy', 5.00426772644601)
# ('iwan bule', 5.00426772644601)
# ('jawa timur', 5.00426772644601)
# ('kasus ganggu', 5.00426772644601)
# ('kobar api', 5.00426772644601)
# ('korban kanjuruhan', 5.00426772644601)
# ('korban tinggal', 5.00426772644601)
# ('kubah masjid', 5.00426772644601)
# ('kurang pakem', 5.00426772644601)
# ('media sosial', 5.00426772644601)
# ('narasi dai', 5.00426772644601)
# ('obat sirup', 5.00426772644601)
# ('polda jawa', 5.00426772644601)
# ('presiden fifa', 5.00426772644601)
# ('rem banget', 5.00426772644601)
# ('satlantas polres', 5.00426772644601)
# ('stadion kanjuruhan', 5.00426772644601)
# ('tanggung jawab', 5.00426772644601)
# ('tech it', 5.00426772644601)
# ('abis ngebunuh', 4.598802618337844)
# ('ada aja', 4.598802618337844)
# ('ada tau', 4.598802618337844)
# ('adem adem', 4.598802618337844)
# ('adem aja', 4.598802618337844)
# ('air mata', 4.598802618337844)
# ('aja amunisi', 4.598802618337844)
# ('aja guru', 4.598802618337844)
# ('aja kasihan', 4.598802618337844)
# ('aja materi', 4.598802618337844)
# ('akhir periksa', 4.598802618337844)
# ('akibat peristiwa', 4.598802618337844)
# ('akp irfan', 4.598802618337844)
# ('akp khapandi', 4.598802618337844)
# ('aksi solidaritas', 4.598802618337844)
# ('akut anak', 4.598802618337844)
# ('akut belum', 4.598802618337844)
# ('akut progresif', 4.598802618337844)
# ('akut serang', 4.598802618337844)
# ('alas iwan', 4.598802618337844)
# ('alas suporter', 4.598802618337844)
# ('alinyemen jalan', 4.598802618337844)
# ('amat hilang', 4.598802618337844)
# ('amunisi kominfo', 4.598802618337844)
# ('anak anak', 4.598802618337844)
# ('anak indonesia', 4.598802618337844)
# ('anak rumah', 4.598802618337844)
# ('anggota kom', 4.598802618337844)
# ('anggota pssi', 4.598802618337844)
# ('aniaya murid', 4.598802618337844)
# ('apa aja', 4.598802618337844)
# ('apa dua', 4.598802618337844)
# ('apa etilen', 4.598802618337844)
# ('api baru', 4.598802618337844)
# ('api besar', 4.598802618337844)
# ('api mulai', 4.598802618337844)
# ('arah fifa', 4.598802618337844)
# ('arah trib', 4.598802618337844)
# ('arema tinggal', 4.598802618337844)
# ('army jangan', 4.598802618337844)
# ('asn milenial', 4.598802618337844)
# ('atas tragedi', 4.598802618337844)
# ('atipikal indonesia', 4.598802618337844)
# ('atur protes', 4.598802618337844)
# ('autopsi korban', 4.598802618337844)
# ('ayah tonton', 4.598802618337844)
# ('bahaya obat', 4.598802618337844)
# ('bakal bawa', 4.598802618337844)
# ('bakal efektif', 4.598802618337844)
# ('bakal gimana', 4.598802618337844)
# ('bakal ikut', 4.598802618337844)
# ('bakal jos', 4.598802618337844)
# ('bakal kumpul', 4.598802618337844)
# ('bakal sulit', 4.598802618337844)
# ('bakar daerah', 4.598802618337844)
# ('bakar jumlah', 4.598802618337844)
# ('bakar mula', 4.598802618337844)
# ('bakar rabu', 4.598802618337844)
# ('bal makan', 4.598802618337844)
# ('balita makin', 4.598802618337844)
# ('banget abis', 4.598802618337844)
# ('banget drone', 4.598802618337844)
# ('banget rekam', 4.598802618337844)
# ('bangun gagas', 4.598802618337844)
# ('bangun leleh', 4.598802618337844)
# ('bangun renovasi', 4.598802618337844)
# ('banjir di', 4.598802618337844)
# ('banjir longsor', 4.598802618337844)
# ('bantu wujud', 4.598802618337844)
# ('banyak banget', 4.598802618337844)
# ('banyak oran', 4.598802618337844)
# ('banyak pihak', 4.598802618337844)
# ('banyak video', 4.598802618337844)
# ('banyak ya', 4.598802618337844)
# ('baru buat', 4.598802618337844)
# ('baru padam', 4.598802618337844)
# ('baru rasa', 4.598802618337844)
# ('baru upa', 4.598802618337844)
# ('batal keluarga', 4.598802618337844)
# ('bawah tech', 4.598802618337844)
# ('bebas ekspres', 4.598802618337844)
# ('beberapa tembak', 4.598802618337844)
# ('beli kasih', 4.598802618337844)
# ('belum identifikasi', 4.598802618337844)
# ('belum yakin', 4.598802618337844)
# ('benar periksa', 4.598802618337844)
# ('beneran kan', 4.598802618337844)
# ('besar banget', 4.598802618337844)
# ('bilang autopsi', 4.598802618337844)
# ('bilang polisi', 4.598802618337844)
# ('bintan akp', 4.598802618337844)
# ('bintan buat', 4.598802618337844)
# ('bintan mukim', 4.598802618337844)
# ('bisa bantu', 4.598802618337844)
# ('bisa campur', 4.598802618337844)
# ('bisa suasana', 4.598802618337844)
# ('blt sesuai', 4.598802618337844)
# ('bola dunia', 4.598802618337844)
# ('bola indonesia', 4.598802618337844)
# ('bola kawan', 4.598802618337844)
# ('bola terus', 4.598802618337844)
# ('bpom narasi', 4.598802618337844)
# ('bts bakal', 4.598802618337844)
# ('buat anak', 4.598802618337844)
# ('buat army', 4.598802618337844)
# ('buat bts', 4.598802618337844)
# ('buat layan', 4.598802618337844)
# ('buat ngeberantas', 4.598802618337844)
# ('buat penuh', 4.598802618337844)
# ('budi gunadi', 4.598802618337844)
# ('bule akhir', 4.598802618337844)
# ('bule enggak', 4.598802618337844)
# ('bus jelas', 4.598802618337844)
# ('butuh cuma', 4.598802618337844)
# ('butuh listrik', 4.598802618337844)
# ('campur itu', 4.598802618337844)
# ('cek deh', 4.598802618337844)
# ('celaka libat', 4.598802618337844)
# ('center koja', 4.598802618337844)
# ('cibubur sopir', 4.598802618337844)
# ('coba cek', 4.598802618337844)
# ('coba deh', 4.598802618337844)
# ('cuma keluarga', 4.598802618337844)
# ('cuma realitas', 4.598802618337844)
# ('daerah mukim', 4.598802618337844)
# ('daftar obat', 4.598802618337844)
# ('dalam bakar', 4.598802618337844)
# ('dari segi', 4.598802618337844)
# ('dasar hasil', 4.598802618337844)
# ('data umum', 4.598802618337844)
# ('datang penuh', 4.598802618337844)
# ('deh narasi', 4.598802618337844)
# ('deh siapa', 4.598802618337844)
# ('deh simak', 4.598802618337844)
# ('deh transisi', 4.598802618337844)
# ('di mana', 4.598802618337844)
# ('dibayangin rem', 4.598802618337844)
# ('dietilen glikol', 4.598802618337844)
# ('dingin dalam', 4.598802618337844)
# ('dokter nyimpen', 4.598802618337844)
# ('dong bawah', 4.598802618337844)
# ('drone kamikaze', 4.598802618337844)
# ('drone tilang', 4.598802618337844)
# ('dua sama', 4.598802618337844)
# ('duka banyak', 4.598802618337844)
# ('duka kanjuruhan', 4.598802618337844)
# ('duka korban', 4.598802618337844)
# ('duka yang', 4.598802618337844)
# ('dukung materiil', 4.598802618337844)
# ('dukung pssi', 4.598802618337844)
# ('dunia ikut', 4.598802618337844)
# ('dunia selalu', 4.598802618337844)
# ('edar media', 4.598802618337844)
# ('efektif buat', 4.598802618337844)
# ('efektif enggak', 4.598802618337844)
# ('ekang bebas', 4.598802618337844)
# ('ekspres juga', 4.598802618337844)
# ('energi baru', 4.598802618337844)
# ('enggak datang', 4.598802618337844)
# ('enggak guna', 4.598802618337844)
# ('enggak pake', 4.598802618337844)
# ('etilen glikol', 4.598802618337844)
# ('fasilitas bakal', 4.598802618337844)
# ('fasilitas stadion', 4.598802618337844)
# ('fifa dukung', 4.598802618337844)
# ('fifa jadi', 4.598802618337844)
# ('fifa malah', 4.598802618337844)
# ('fifa pssi', 4.598802618337844)
# ('football iwan', 4.598802618337844)
# ('fun football', 4.598802618337844)
# ('gagal minta', 4.598802618337844)
# ('gagas sampai', 4.598802618337844)

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %% [markdown]
# ## Cek Politik Non Politik untuk semua Label

# %%
tfidf_vect = TfidfVectorizer(ngram_range = (2,2))

# %%
Data_TFIDF = tfidf_vect.fit_transform(dataset["ProcessedText"].values)

# %%
Data_TFIDF.shape
# Out:
# (100, 1085)

# %% [markdown]
# ## Training dan Testing membagi menjadi 70 - 30

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split

# %%
train_TFIDF, test_TFIDF, train_labels_TFIDF, test_labels_TFIDF = train_test_split(dataset_feature, dataset_label, test_size = 0.3, random_state=42)

# %%
train_TFIDF.shape, test_TFIDF.shape, train_labels_TFIDF.shape, test_labels_TFIDF.shape
# Out:
# ((70,), (30,), (70,), (30,))

# %% [markdown]
# ## Model Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
classifier_nb = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('model', MultinomialNB()),
])

# %%
parameters_nb = {
    'tfidf__ngram_range': [(2, 2)],
    'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100)
}

# %%
classifier_nb = GridSearchCV(classifier_nb, parameters_nb, cv = 3, n_jobs=-1)

# %%
classifier_nb.fit(train_TFIDF, train_labels_TFIDF.ravel())
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('model', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100),
#                          'tfidf__ngram_range': [(2, 2)]})

# %% [markdown]
# ## Nilai Accuracy Training Set dan Test Set

# %%
y_pred_nb_train = classifier_nb.predict(train_TFIDF)
accuracy_nb_train = accuracy_score(train_labels_TFIDF, y_pred_nb_train)
print("Accuracy Training set: ", accuracy_nb_train)

y_pred_nb_test = classifier_nb.predict(test_TFIDF)
accuracy_nb_test = accuracy_score(test_labels_TFIDF, y_pred_nb_test)
print("Accuracy Test set: ", accuracy_nb_test)
# Out:
# Accuracy Training set:  1.0
# Accuracy Test set:  0.7333333333333333

# %% [markdown]
# ## Nilai Recall Training Set dan Test Set

# %%
recall_nb_train = recall_score(train_labels_TFIDF, y_pred_nb_train, average='weighted')
print("Recall Training set: ", recall_nb_train)

recall_nb_test = recall_score(test_labels_TFIDF, y_pred_nb_test, average='weighted')
print("Recall Test set: ", recall_nb_test)
# Out:
# Recall Training set:  1.0
# Recall Test set:  0.7333333333333333

# %% [markdown]
# ## Nilai Precission Training Set dan Test Set

# %%
precision_nb_train = precision_score(train_labels_TFIDF, y_pred_nb_train, average='weighted')
print("Precision Training set: ", precision_nb_train)

precision_nb_test = precision_score(test_labels_TFIDF, y_pred_nb_test, average='weighted')
print("Precision Test set: ", precision_nb_test)
# Out:
# Precision Training set:  1.0
# Precision Test set:  0.7493333333333333

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(test_labels_TFIDF, y_pred_nb_test), annot=True, cmap = 'viridis', fmt='.0f')
plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)
plt.show()

# %% [markdown]
# Bisa kita lhat bahwa nilai dari TP(1,1) yakni 4 dan TN(0,0) 18 sementara nilai FP(0,1) 1 dan FN (1,0) 7.

# %% [markdown]
# ## Visualisasi

# %%
models = [
          ('Naive Bayes Multinomial', accuracy_nb_train, accuracy_nb_test),                    
         ]

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'Training Accuracy', 'Test Accuracy'])
predict
# Out:
#                      Model  Training Accuracy  Test Accuracy
# 0  Naive Bayes Multinomial                1.0       0.733333

# %%
models_comparison = [
                        ('Naive Bayes Multinomial', accuracy_nb_test, recall_nb_test, precision_nb_test),                          
                    ]

# %%
comparison = pd.DataFrame(data = models_comparison, columns=['Model', 'Accuracy', 'Recall', 'Precision'])
comparison
# Out:
#                      Model  Accuracy    Recall  Precision
# 0  Naive Bayes Multinomial  0.733333  0.733333   0.749333

# %%
import numpy as np

f, axes = plt.subplots(2,1, figsize=(14,10))

predict.sort_values(by=['Training Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Training Accuracy', y='Model', data = predict, palette='Blues_d', ax = axes[0])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[0].set_xlabel('Training Accuracy', size=16)
axes[0].set_ylabel('Model')
axes[0].set_xlim(0,1.0)
axes[0].set_xticks(np.arange(0, 1.1, 0.1))

predict.sort_values(by=['Test Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Test Accuracy', y='Model', data = predict, palette='Greens_d', ax = axes[1])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[1].set_xlabel('Test Accuracy', size=16)
axes[1].set_ylabel('Model')
axes[1].set_xlim(0,1.0)
axes[1].set_xticks(np.arange(0, 1.1, 0.1))

plt.show()

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# - Dari hasil diatas dapat dilihat bahwa dari dataset sesudah dilakukan proses pre processing (normalisasi kata slang dan stemming) namun pada bagian klasifiasi ngram disini saya menggunakan bigrams (2,2) memperoleh nilai akurasi dari dataset training dan dataset testing yang tingkat keakurasian yang cukup jauh. Nilai yang diperoleh untuk dataset traning sebesar 1.0 sedangkan untuk dataset testing 0.73. Dari sini dapat disimpulkan bahwa proses pre processing dengan klasifikasi ngram (2,2) nilainya lebih rendah jika dibandingkan dengan klasifikasi ngram (1,2)
